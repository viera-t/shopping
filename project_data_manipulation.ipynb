# %%
#mount google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import the data

import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/shopping_trends.csv')
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category Purchase Amount (USD)  \
# 0            1  550   Male         Blouse  Clothing                $53.00
# 1            2   19    NaN        Sweater  Clothing                $64.00
# 2            3   50   Male          Jeans  Clothing                $73.00
# 3            4   21   Male        Sandals  Footwear                $90.00
# 4            5   45   Male         Blouse  Clothing                $49.00
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  wigter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %% [markdown]
# #Lec1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3902 entries, 0 to 3901
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3902 non-null   int64
#  1   Age                       3902 non-null   object
#  2   Gender                    3834 non-null   object
#  3   Item Purchased            3902 non-null   object
#  4   Category                  3902 non-null   object
#  5   Purchase Amount (USD)     3902 non-null   object
#  6   Location                  3902 non-null   object
#  7   Size                      3902 non-null   object
#  8   Color                     3902 non-null   object
#  9   Season                    3902 non-null   object
#  10  Review Rating             3902 non-null   float64
#  11  Subscription Status       3902 non-null   object
#  12  Payment Method            3902 non-null   object
# ...

# %%
df.count()
# Out:
# Customer ID                 3902
# Age                         3902
# Gender                      3834
# Item Purchased              3902
# Category                    3902
# Purchase Amount (USD)       3902
# Location                    3902
# Size                        3902
# Color                       3902
# Season                      3902
# Review Rating               3902
# Subscription Status         3902
# Payment Method              3902
# Shipping Type               3902
# Discount Applied            3839
# Promo Code Used             3836
# Previous Purchases          3902
# Preferred Payment Method    3902
# Frequency of Purchases      3902
# dtype: int64

# %%
df.shape
# Out:
# (3902, 19)

# %%
df.describe()
# Out:
#        Customer ID  Review Rating  Previous Purchases
# count  3902.000000    3902.000000         3902.000000
# mean   1951.498975       3.749795           25.353152
# std    1126.552930       0.716115           14.443956
# min       1.000000       2.500000            1.000000
# 25%     976.250000       3.100000           13.000000
# 50%    1951.500000       3.700000           25.000000
# 75%    2926.750000       4.400000           38.000000
# max    3900.000000       5.000000           50.000000

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# #Lec2 Cleaning Data Find missing data/Find outliers

# %%
import numpy as np

np.NaN
pd.NA
None

# %%
df.dtypes
# Out:
# Customer ID                   int64
# Age                          object
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)        object
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df.isna()
# Out:
#       Customer ID    Age  Gender  Item Purchased  Category  \
# 0           False  False   False           False     False
# 1           False  False    True           False     False
# 2           False  False   False           False     False
# 3           False  False   False           False     False
# 4           False  False   False           False     False
# ...           ...    ...     ...             ...       ...
# 3897        False  False   False           False     False
# 3898        False  False   False           False     False
# 3899        False  False   False           False     False
# 3900        False  False   False           False     False
# 3901        False  False   False           False     False
#
#       Purchase Amount (USD)  Location   Size  Color  Season  Review Rating  \
# 0                     False     False  False  False   False          False
# 1                     False     False  False  False   False          False
# ...

# %%
df.isna().sum()
# Out:
# Customer ID                  0
# Age                          0
# Gender                      68
# Item Purchased               0
# Category                     0
# Purchase Amount (USD)        0
# Location                     0
# Size                         0
# Color                        0
# Season                       0
# Review Rating                0
# Subscription Status          0
# Payment Method               0
# Shipping Type                0
# Discount Applied            63
# Promo Code Used             66
# Previous Purchases           0
# Preferred Payment Method     0
# Frequency of Purchases       0
# dtype: int64

# %%
# Rows with any NaNs
df[df.isna().any(axis=1)]
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1  550    Male         Blouse     Clothing
# 1               2   19     NaN        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 7               8   27     NaN         Shorts     Clothing
# 8               9   26    Male           Coat    Outerwear
# ...           ...  ...     ...            ...          ...
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900  52y  Female        Handbag  Accessories
# 3900         3899   44  Female          Shoes     Footwear
# 3901         3900  52y  Female        Handbag  Accessories
#
#      Purchase Amount (USD)       Location Size     Color  Season  \
# 0                   $53.00       Kentucky    L      Gray  Winter
# 1                   $64.00          Maine    L    Maroon  wigter
# ...

# %%
# แทนที่ค่าที่หายไปในคอลัมน์ 'Discount Applied' ด้วย "NO"
df['Discount Applied'].fillna("NO", inplace=True)
# แทนที่ค่าที่หายไปในคอลัมน์ 'Promo Code Used' ด้วย "NO"
df['Promo Code Used'].fillna("NO", inplace=True)
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1  550    Male         Blouse     Clothing
# 1               2   19     NaN        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900  52y  Female        Handbag  Accessories
# 3900         3899   44  Female          Shoes     Footwear
# 3901         3900  52y  Female        Handbag  Accessories
#
#      Purchase Amount (USD)       Location Size      Color  Season  \
# 0                   $53.00       Kentucky    L       Gray  Winter
# 1                   $64.00          Maine    L     Maroon  wigter
# ...

# %%
df.dropna(subset=['Gender'], inplace=True)
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1  550    Male         Blouse     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# 5               6   46    Male       Sneakers     Footwear
# ...           ...  ...     ...            ...          ...
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900  52y  Female        Handbag  Accessories
# 3900         3899   44  Female          Shoes     Footwear
# 3901         3900  52y  Female        Handbag  Accessories
#
#      Purchase Amount (USD)       Location Size      Color  Season  \
# 0                   $53.00       Kentucky    L       Gray  Winter
# 2                   $73.00  Massachusetts    S     Maroon  Spring
# ...

# %%
df[df.Gender.isna()]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Age, Gender, Item Purchased, Category, Purchase Amount (USD), Location, Size, Color, Season, Review Rating, Subscription Status, Payment Method, Shipping Type, Discount Applied, Promo Code Used, Previous Purchases, Preferred Payment Method, Frequency of Purchases]
# Index: []

# %%
df.Age.value_counts()
# Out:
# 69     87
# 25     85
# 57     85
# 41     84
# 54     83
#        ..
# 550     1
# 42y     1
# 57y     1
# 61y     1
# 55y     1
# Name: Age, Length: 62, dtype: int64

# %%
# ทำการแทนค่าในคอลัมน์ "Age" โดยลบตัวอักษร "y" ออก
df['Age'] = df['Age'].str.replace('y', '')

# แปลงค่าในคอลัมน์ "Age" ให้เป็นตัวเลข
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# %%
df['Age'] = np.where(df['Age'] > 90, 90, df['Age'])
df.Age.value_counts()
# Out:
# 69    87
# 57    86
# 25    85
# 41    84
# 54    83
# 50    82
# 49    82
# 62    82
# 58    81
# 27    81
# 32    80
# 19    79
# 42    79
# 28    79
# 43    78
# 37    76
# 46    76
# 31    76
# 29    75
# 52    74
# 36    74
# 68    74
# 63    73
# 64    73
# 59    72
# 45    72
# 51    72
# 56    72
# 23    71
# 47    71
# 38    70
# 40    70
# 30    70
# 35    70
# 55    69
# 66    69
# 18    69
# 21    68
# 24    67
# 53    67
# 26    66
# 34    66
# 48    66
# 39    66
# 65    66
# 22    65
# 61    65
# 60    64
# 70    64
# 20    62
# 33    62
# 67    53
# 44    50
# 90     1
# Name: Age, dtype: int64

# %%
df['Payment Method'].value_counts()
# Out:
# Credit Card      685
# Cash             639
# Venmo            638
# Debit Card       625
# Bank Transfer    618
# PayPal           607
# "PayPal"          22
# Name: Payment Method, dtype: int64

# %%
# ใช้ str.replace() เพื่อลบเครื่องหมาย " ในคอลัมน์ 'Payment Method'
df['Payment Method'] = df['Payment Method'].str.replace('"', '')
df['Payment Method'].value_counts()
# Out:
# Credit Card      685
# Cash             639
# Venmo            638
# PayPal           629
# Debit Card       625
# Bank Transfer    618
# Name: Payment Method, dtype: int64

# %%
df['Purchase Amount (USD)'].value_counts()
# Out:
# $94.00     61
# $32.00     60
# $51.00     60
# $90.00     59
# $36.00     59
#            ..
# $87.00     35
# $100.00    35
# $49.00     34
# $61.00     33
# $69.00     32
# Name: Purchase Amount (USD), Length: 81, dtype: int64

# %%
# ใช้ str.replace() เพื่อลบเครื่องหมาย $ ในคอลัมน์ 'Payment Method'
df['Purchase Amount (USD)'] = df['Purchase Amount (USD)'].str.replace('$', '')

# แปลงค่าในคอลัมน์ "Purchase Amount (USD" ให้เป็นตัวเลข
df['Purchase Amount (USD'] = pd.to_numeric(df['Purchase Amount (USD)'], errors='coerce')
df['Purchase Amount (USD)'].value_counts()
# Out:
# <ipython-input-22-ec2e7d629243>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Purchase Amount (USD)'] = df['Purchase Amount (USD)'].str.replace('$', '')
# 94.00     61
# 32.00     60
# 51.00     60
# 90.00     59
# 36.00     59
#           ..
# 87.00     35
# 100.00    35
# 49.00     34
# 61.00     33
# 69.00     32
# Name: Purchase Amount (USD), Length: 81, dtype: int64

# %%
df['Season'].value_counts()
# Out:
# Spring    985
# Fall      955
# Summer    939
# Winter    933
# wigter     22
# Name: Season, dtype: int64

# %%
# ใช้ str.replace() เพื่อเปลี่ยน wigter เป็น Winter ในคอลัมน์ 'Season'
df['Season'] = df['Season'].str.replace('wigter', 'Winter')

df['Season'].value_counts()
# Out:
# Spring    985
# Winter    955
# Fall      955
# Summer    939
# Name: Season, dtype: int64

# %%
df.isna().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# Purchase Amount (USD        0
# dtype: int64

# %%
df['Payment Method'].value_counts()
# Out:
# Credit Card      685
# Cash             639
# Venmo            638
# PayPal           629
# Debit Card       625
# Bank Transfer    618
# Name: Payment Method, dtype: int64

# %%
df['Preferred Payment Method'].value_counts()
# Out:
# PayPal           666
# Cash             659
# Credit Card      658
# Debit Card       628
# Venmo            621
# Bank Transfer    602
# Name: Preferred Payment Method, dtype: int64

# %%
df['Shipping Type'].value_counts()
# Out:
# Free Shipping     662
# Next Day Air      640
# Store Pickup      640
# Standard          638
# Express           636
# 2-Day Shipping    618
# Name: Shipping Type, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Clothing       1696
# Accessories    1229
# Footwear        592
# Outerwear       317
# Name: Category, dtype: int64

# %%
df['Location'].value_counts()
# Out:
# Montana           96
# California        96
# Idaho             92
# Illinois          89
# Alabama           88
# Minnesota         88
# Nebraska          85
# Nevada            85
# Delaware          85
# Maryland          84
# Vermont           83
# New York          83
# Louisiana         82
# Missouri          81
# West Virginia     81
# New Mexico        80
# North Dakota      80
# Kentucky          79
# Indiana           79
# Georgia           79
# Arkansas          78
# Connecticut       77
# North Carolina    76
# Maine             76
# Mississippi       76
# Tennessee         76
# Ohio              76
# South Carolina    75
# Virginia          75
# Texas             74
# Washington        73
# Oklahoma          73
# Wisconsin         73
# Colorado          72
# Pennsylvania      72
# Alaska            71
# Massachusetts     71
# Oregon            71
# Michigan          71
# Utah              70
# Iowa              69
# South Dakota      69
# Wyoming           69
# ...

# %%
df['Season'].value_counts()
# Out:
# Spring    985
# Winter    955
# Fall      955
# Summer    939
# Name: Season, dtype: int64

# %% [markdown]
# ##Standard deviation

# %%
import numpy as np

# calculate the mean and standard deviation
mean = np.mean(df['Review Rating'])
sd = np.std(df['Review Rating'])

# show mean and standard deviation
mean, sd
# Out:
# (3.7496870109546165, 0.71707773347881)

# %%
# calculate the mean and standard deviation
mean = np.mean(df['Age'])
sd = np.std(df['Age'])

# show mean and standard deviation
mean, sd
# Out:
# (44.0339071465832, 15.211957450334035)

# %%
# view all ordered Review Rating
df['Review Rating'].sort_values()
# Out:
# 482     2.5
# 2724    2.5
# 2731    2.5
# 2739    2.5
# 3413    2.5
#        ...
# 1820    5.0
# 2632    5.0
# 1339    5.0
# 3844    5.0
# 2193    5.0
# Name: Review Rating, Length: 3834, dtype: float64

# %%
# view all ordered Review Rating
df['Age'].sort_values()
# Out:
# 1869    18
# 1922    18
# 3610    18
# 3467    18
# 3559    18
#         ..
# 1271    70
# 325     70
# 3373    70
# 384     70
# 0       90
# Name: Age, Length: 3834, dtype: int64

# %% [markdown]
# #Lec3

# %% [markdown]
# Filtering

# %%
df[df['Season'] == 'Winter']
# Out:
#       Customer ID  Age  Gender Item Purchased   Category  \
# 0               1   90    Male         Blouse   Clothing
# 11             12   30    Male         Shorts   Clothing
# 12             13   61    Male           Coat  Outerwear
# 14             15   64    Male           Coat  Outerwear
# 15             16   64    Male          Skirt   Clothing
# ...           ...  ...     ...            ...        ...
# 3879         3880   26  Female          Skirt   Clothing
# 3880         3881   42  Female          Shirt   Clothing
# 3885         3886   49  Female          Socks   Clothing
# 3890         3891   35  Female          Shirt   Clothing
# 3891         3892   36  Female          Dress   Clothing
#
#      Purchase Amount (USD)       Location Size   Color  Season  Review Rating  \
# 0                    53.00       Kentucky    L    Gray  Winter            3.1
# 11                   68.00         Hawaii    S   Olive  Winter            4.9
# ...

# %%
df.loc[df['Season'] == 'Winter', ['Item Purchased','Purchase Amount (USD)']]
# Out:
#      Item Purchased Purchase Amount (USD)
# 0            Blouse                 53.00
# 11           Shorts                 68.00
# 12             Coat                 72.00
# 14             Coat                 53.00
# 15            Skirt                 81.00
# ...             ...                   ...
# 3879          Skirt                 63.00
# 3880          Shirt                 20.00
# 3885          Socks                 64.00
# 3890          Shirt                 81.00
# 3891          Dress                 30.00
#
# [955 rows x 2 columns]

# %%
df.loc[df.Category == 'Outerwear']
# Out:
#       Customer ID  Age  Gender Item Purchased   Category  \
# 8               9   26    Male           Coat  Outerwear
# 12             13   61    Male           Coat  Outerwear
# 14             15   64    Male           Coat  Outerwear
# 24             25   18    Male         Jacket  Outerwear
# 32             33   36    Male         Jacket  Outerwear
# ...           ...  ...     ...            ...        ...
# 3842         3843   35  Female         Jacket  Outerwear
# 3861         3862   64  Female         Jacket  Outerwear
# 3867         3868   46  Female         Jacket  Outerwear
# 3869         3870   26  Female           Coat  Outerwear
# 3872         3873   41  Female         Jacket  Outerwear
#
#      Purchase Amount (USD)       Location Size     Color  Season  \
# 8                    97.00  West Virginia    L    Silver  Summer
# 12                   72.00       Delaware    M      Gold  Winter
# 14                   53.00       New York    L      Teal  Winter
# ...

# %%
mask = (df['Season'] == 'Winter') & (df.Category == 'Outerwear')
df[mask]
# Out:
#       Customer ID  Age  Gender Item Purchased   Category  \
# 12             13   61    Male           Coat  Outerwear
# 14             15   64    Male           Coat  Outerwear
# 55             56   40    Male         Jacket  Outerwear
# 67             68   45    Male           Coat  Outerwear
# 79             80   38    Male         Jacket  Outerwear
# ...           ...  ...     ...            ...        ...
# 3591         3592   48  Female         Jacket  Outerwear
# 3728         3729   62  Female         Jacket  Outerwear
# 3752         3753   24  Female           Coat  Outerwear
# 3799         3800   60  Female         Jacket  Outerwear
# 3842         3843   35  Female         Jacket  Outerwear
#
#      Purchase Amount (USD)        Location Size     Color  Season  \
# 12                   72.00        Delaware    M      Gold  Winter
# 14                   53.00        New York    L      Teal  Winter
# 55                   28.00  South Carolina    M  Lavender  Winter
# ...

# %%
df[df['Item Purchased'] == 'Jeans']
# Out:
#       Customer ID  Age  Gender Item Purchased  Category Purchase Amount (USD)  \
# 2               3   50    Male          Jeans  Clothing                 73.00
# 37             38   35    Male          Jeans  Clothing                 45.00
# 98             99   20    Male          Jeans  Clothing                 67.00
# 227           228   50    Male          Jeans  Clothing                 90.00
# 259           260   32    Male          Jeans  Clothing                 57.00
# ...           ...  ...     ...            ...       ...                   ...
# 3736         3737   42  Female          Jeans  Clothing                 56.00
# 3779         3780   60  Female          Jeans  Clothing                 75.00
# 3785         3786   64  Female          Jeans  Clothing                 94.00
# 3840         3841   30  Female          Jeans  Clothing                 42.00
# 3841         3842   68  Female          Jeans  Clothing                 57.00
#
# ...

# %%
df.loc[df['Promo Code Used'] == 'Yes'].reset_index().head(5)
# Out:
#    index  Customer ID  Age Gender Item Purchased  Category  \
# 0      0            1   90   Male         Blouse  Clothing
# 1      3            4   21   Male        Sandals  Footwear
# 2      4            5   45   Male         Blouse  Clothing
# 3      5            6   46   Male       Sneakers  Footwear
# 4      6            7   63   Male          Shirt  Clothing
#
#   Purchase Amount (USD)      Location Size      Color  ... Review Rating  \
# 0                 53.00      Kentucky    L       Gray  ...           3.1
# 1                 90.00  Rhode Island    M     Maroon  ...           3.5
# 2                 49.00        Oregon    M  Turquoise  ...           2.7
# 3                 20.00       Wyoming    M      White  ...           2.9
# 4                 85.00       Montana    M       Gray  ...           3.2
#
#    Subscription Status Payment Method  Shipping Type Discount Applied  \
# 0                  Yes    Credit Card        Express               NO
# ...

# %%
df.loc[df['Item Purchased'] == 'Shorts', ['Purchase Amount (USD)', 'Size']]
# Out:
#      Purchase Amount (USD) Size
# 11                   68.00    S
# 27                   56.00    L
# 121                  72.00    M
# 125                  54.00    M
# 126                  36.00    L
# ...                    ...  ...
# 3824                 26.00    M
# 3825                 35.00    L
# 3844                 87.00    S
# 3859                 88.00    S
# 3865                 42.00    M
#
# [152 rows x 2 columns]

# %%
df['Frequency of Purchases'].value_counts().reset_index().head()
# Out:
#             index  Frequency of Purchases
# 0  Every 3 Months                     573
# 1        Annually                     564
# 2       Quarterly                     556
# 3         Monthly                     546
# 4       Bi-Weekly                     539

# %% [markdown]
# Sorting

# %%
df[['Season', 'Purchase Amount (USD)', 'Category']].sort_values('Category', ascending=False).head(10)
# Out:
#       Season Purchase Amount (USD)   Category
# 2549    Fall                 60.00  Outerwear
# 541     Fall                 27.00  Outerwear
# 1713  Winter                 22.00  Outerwear
# 2838    Fall                 50.00  Outerwear
# 3109  Winter                 92.00  Outerwear
# 973     Fall                 75.00  Outerwear
# 731   Spring                 28.00  Outerwear
# 2834    Fall                 43.00  Outerwear
# 1356  Spring                 61.00  Outerwear
# 982   Summer                 62.00  Outerwear

# %%
df.groupby(['Season', 'Item Purchased'])['Category'].count().reset_index().sort_values('Category', ascending=False).groupby('Season').head()
# Out:
#     Season Item Purchased  Category
# 10    Fall         Jacket        51
# 97  Winter     Sunglasses        51
# 48  Spring        Sweater        51
# 88  Winter          Pants        50
# 8     Fall            Hat        50
# 63  Summer          Pants        50
# 91  Winter          Shirt        49
# 7     Fall        Handbag        48
# 87  Winter        Jewelry        47
# 84  Winter         Hoodie        46
# 29  Spring           Coat        46
# 27  Spring         Blouse        46
# 62  Summer        Jewelry        46
# 67  Summer          Shoes        46
# 55  Summer          Dress        45
# 19    Fall          Skirt        45
# 43  Spring         Shorts        45
# 44  Spring          Skirt        45
# 14    Fall        Sandals        44
# 50  Summer       Backpack        43

# %%
df.groupby('Shipping Type').size().sort_values(ascending=False).reset_index().head()
# Out:
#    Shipping Type    0
# 0  Free Shipping  662
# 1   Next Day Air  640
# 2   Store Pickup  640
# 3       Standard  638
# 4        Express  636

# %% [markdown]
# Grouping

# %%
df.groupby('Category')['Review Rating'].mean().reset_index()
# Out:
#       Category  Review Rating
# 0  Accessories       3.769894
# 1     Clothing       3.721639
# 2     Footwear       3.789358
# 3    Outerwear       3.747319

# %%
df.groupby('Category')['Review Rating'].max().reset_index().head(1)
# Out:
#       Category  Review Rating
# 0  Accessories            5.0

# %%
df.groupby('Category')['Review Rating'].min().reset_index().head(1)
# Out:
#       Category  Review Rating
# 0  Accessories            2.5

# %%
df.groupby('Location')['Frequency of Purchases'].count().reset_index().sort_values('Frequency of Purchases', ascending=False).head(5)
# Out:
#       Location  Frequency of Purchases
# 25     Montana                      96
# 4   California                      96
# 11       Idaho                      92
# 12    Illinois                      89
# 22   Minnesota                      88
